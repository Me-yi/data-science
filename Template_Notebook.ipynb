# %% [markdown]
# # \<Template Notebook\>

# %% [markdown]
# ## Environment Requirements
#
# **Python**: `v3.14.2`

# %% [markdown]
# ## Required imports

# %%
from google.colab import drive
from scipy.stats import uniform, binom, norm, poisson, expon, t, lognorm
# from pathlib import Path

import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data sources

# %% [markdown]
# ### Mounting Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Get DataFrame

# %%
def get_df(file_name: str, **read_csv_options):
  """Get DataFrame from personal Google Drive CSV file"""
  gd_dir_location = '/content/drive/My Drive/Colab Notebooks/data/learning/'
  return pd.read_csv(gd_dir_location + file_name, index_col=0, **read_csv_options)

# %%
# Used for local data
#
# def get_df(file_name: str):
#   filepath = Path("..")/"data"/file_name
#   return pd.read_csv(filepath, index_col=0)

# %% [markdown]
# ### Sources

# %%
amir_deals = get_df('amir_deals.csv')
world_happiness = get_df('world_happiness.csv')

# %% [markdown]
# ## \<Sub heading\>

# %% [markdown]
# Subheading description.

# %%
amir_deals.head()
# Out:
#      product   client status   amount  num_users
# 1  Product F  Current    Won  7389.52         19
# 2  Product C      New    Won  4493.01         43
# 3  Product B      New    Won  5738.09         87
# 4  Product I  Current    Won  2591.24         83
# 5  Product E  Current    Won  6622.97         17

# %%
amir_deals['amount_per_user'] = round(amir_deals['amount'] / amir_deals['num_users'], 2)
amir_deals.head()
# Out:
#      product   client status   amount  num_users  amount_per_user
# 1  Product F  Current    Won  7389.52         19           388.92
# 2  Product C      New    Won  4493.01         43           104.49
# 3  Product B      New    Won  5738.09         87            65.96
# 4  Product I  Current    Won  2591.24         83            31.22
# 5  Product E  Current    Won  6622.97         17           389.59
