# %% [markdown]
# # Best Practices
#
# ## Data checks
#
# - **Data Array Length**:  check that data array length is consistently the same - use `len()`
# - **Finalise \*.ipynb file**: remember to run all cells before saving
